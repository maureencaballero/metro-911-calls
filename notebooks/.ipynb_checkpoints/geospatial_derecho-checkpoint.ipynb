# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import datetime as dt

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')

# %%
zipcodes.loc[0, 'geometry']

# %%
tornado_911 = pd.read_csv( '../data/911_Phone_Calls_Tornado_030320.csv')
derecho_911 = pd.read_csv('../data/911_Phone Calls_Derecho_050320 050420.csv')
tornado_dispact = pd.read_csv('../data/Computer Aided Dispatch Data_Tornado Incidents 030320.csv', skiprows=2)
derecho_dispatch = pd.read_csv('../data/Computer Aided Dispatch Data_Derecho Incidents 050320-050420.csv', skiprows=2)

# %%
print(derecho_dispatch)
# Out:
#              IncidentDate            Location  Latitude1  Longitude1  \
# 0     5/3/2020 4:31:07 PM    901 KENWICK CT W  36.046877  -86.962526
# 1     5/3/2020 4:32:18 PM       8036 ARBOR DR  36.082491  -86.940680
# 2     5/3/2020 4:32:23 PM   119 DUE WEST AV E  36.248029  -86.716875
# 3     5/3/2020 4:33:04 PM  630 GALLATIN PKE S  36.256491  -86.714817
# 4     5/3/2020 4:33:52 PM   615 W HILLWOOD DR  36.129690  -86.879834
# ..                    ...                 ...        ...         ...
# 622  5/4/2020 12:21:00 AM       625 BENTON AV  36.131384  -86.770628
# 623  5/4/2020 12:21:32 AM    518 BRENTLAWN DR  36.064362  -86.761199
# 624  5/4/2020 12:22:47 AM       517 ALBANY DR  36.212754  -86.600431
# 625  5/4/2020 12:27:52 AM    639 LAFAYETTE ST  36.153769  -86.777520
# 626  5/4/2020 12:29:50 AM      2011 HAYES ST   36.151839  -86.800791
#
#                              IncidentTypeDescription1
# 0                                   ELECTRICAL HAZARD
# 1                                   ELECTRICAL HAZARD
# 2                                      NOT ALERT COPD
# 3                                      ABDOMINAL PAIN
# 4                                   ELECTRICAL HAZARD
# ..                                                ...
# 622                        HIGH RISE NATURAL GAS ODOR
# 623                                    UNKNOWN STATUS
# 624                                 ELECTRICAL HAZARD
# 625                 SICK PERSON: NO PRIORITY SYMPTOMS
# 626  PULL STATION ALARM COMMERCIAL   INDUSTRIAL BUILD
#
# [627 rows x 5 columns]

# %%
derecho_dispatch.dtypes
# Out:
# IncidentDate                 object
# Location                     object
# Latitude1                   float64
# Longitude1                  float64
# IncidentTypeDescription1     object
# dtype: object

# %%
print(derecho_dispatch.columns)
# Out:
# Index(['IncidentDate', 'Location', 'Latitude1', 'Longitude1',
#        'IncidentTypeDescription1'],
#       dtype='object')

# %%
derecho_dispatch.columns = ['Seizure DateTime', 'Location', 'lat', 'lng', 'Incident Type']

# %%
print(derecho_dispatch.head(3))
# Out:
#       Seizure DateTime           Location        lat        lng  \
# 0  5/3/2020 4:31:07 PM   901 KENWICK CT W  36.046877 -86.962526
# 1  5/3/2020 4:32:18 PM      8036 ARBOR DR  36.082491 -86.940680
# 2  5/3/2020 4:32:23 PM  119 DUE WEST AV E  36.248029 -86.716875
#
#        Incident Type
# 0  ELECTRICAL HAZARD
# 1  ELECTRICAL HAZARD
# 2     NOT ALERT COPD

# %%
derecho_dispatch['geometry'] = derecho_dispatch.apply(lambda x: Point((float(x.lng), 
                                                         float(x.lat))), 
                                        axis=1)

# %%
derecho_dispatch_geo = gpd.GeoDataFrame(derecho_dispatch, 
                           crs = zipcodes.crs, 
                           geometry = derecho_dispatch['geometry'])

# %%
zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

# %%
calls_by_zip = gpd.sjoin(derecho_dispatch_geo, zipcodes, op = 'within')

# %%
calls_by_zip.head(5)
# Out:
#         Seizure DateTime              Location        lat        lng  \
# 0    5/3/2020 4:31:07 PM      901 KENWICK CT W  36.046877 -86.962526
# 1    5/3/2020 4:32:18 PM         8036 ARBOR DR  36.082491 -86.940680
# 17   5/3/2020 4:39:57 PM  8715 OLD HARDING PKE  36.012524 -87.024584
# 88   5/3/2020 5:12:40 PM          7205 MARK DR  36.065849 -86.928772
# 116  5/3/2020 5:25:03 PM    1651 CHICKERING RD  36.059848 -86.874532
#
#             Incident Type                    geometry  index_right    zip  \
# 0       ELECTRICAL HAZARD  POINT (-86.96253 36.04688)            7  37221
# 1       ELECTRICAL HAZARD  POINT (-86.94068 36.08249)            7  37221
# 17      ELECTRICAL HAZARD  POINT (-87.02458 36.01252)            7  37221
# 88      ELECTRICAL HAZARD  POINT (-86.92877 36.06585)            7  37221
# 116  ENTRAPMENT / TRAPPED  POINT (-86.87453 36.05985)            7  37221
#
#        po_name
# 0    NASHVILLE
# 1    NASHVILLE
# 17   NASHVILLE
# 88   NASHVILLE
# 116  NASHVILLE

# %%
calls_by_zip['zip'].value_counts()
# Out:
# 37211    79
# 37076    61
# 37205    57
# 37013    56
# 37214    37
# 37215    34
# 37204    29
# 37217    27
# 37221    27
# 37210    26
# 37212    25
# 37209    25
# 37203    20
# 37207    20
# 37220    19
# 37115    15
# 37216    12
# 37208    12
# 37206     9
# 37027     8
# 37138     6
# 37218     6
# 37072     5
# 37080     3
# 37228     2
# 37219     1
# 37232     1
# 37189     1
# 37143     1
# 37201     1
# Name: zip, dtype: int64

# %%
ax = zipcodes.plot(figsize = (8, 10), color = 'lightgreen')
calls_by_zip.plot( ax = ax, column = 'po_name');
plt.show();

# %%
center = calls_by_zip.geometry.centroid[500]
# Out:
# <ipython-input-248-a4d7b2f9bc33>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = calls_by_zip.geometry.centroid[500]

# %%
area_center = [center.y, center.x]

# %%
print(area_center)
# Out:
# [36.16942259, -86.75816033]

# %%
derecho_dispatch_map = folium.Map(location =  area_center, zoom_start = 12)
derecho_dispatch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(derecho_dispatch.head(5))
# Out:
#       Seizure DateTime            Location        lat        lng  \
# 0  5/3/2020 4:31:07 PM    901 KENWICK CT W  36.046877 -86.962526
# 1  5/3/2020 4:32:18 PM       8036 ARBOR DR  36.082491 -86.940680
# 2  5/3/2020 4:32:23 PM   119 DUE WEST AV E  36.248029 -86.716875
# 3  5/3/2020 4:33:04 PM  630 GALLATIN PKE S  36.256491 -86.714817
# 4  5/3/2020 4:33:52 PM   615 W HILLWOOD DR  36.129690 -86.879834
#
#        Incident Type                    geometry
# 0  ELECTRICAL HAZARD  POINT (-86.96253 36.04688)
# 1  ELECTRICAL HAZARD  POINT (-86.94068 36.08249)
# 2     NOT ALERT COPD  POINT (-86.71687 36.24803)
# 3     ABDOMINAL PAIN  POINT (-86.71482 36.25649)
# 4  ELECTRICAL HAZARD  POINT (-86.87983 36.12969)

# %% [markdown]
# #derecho_dispatch['Seizure DateTime'] = pd.to_datetime(derecho_dispatch['Seizure DateTime'])
# derecho_dispatch = derecho_dispatch.resample('15min', on='Seizure DateTime').Incident_Type.count()#

# %%
#start_time = '2020-05-03 16:30:00'
#end_time = '2020-05-03 21:00:00'
#new_derecho_dispatch = derecho_dispatch[(derecho_dispatch['Seizure DateTime'] >= start_time) & (derecho_dispatch['Seizure DateTime'] <= end_time)]

# %%
#new_derecho_plot = new_derecho_dispatch.resample('15min', on='Seizure DateTime').Incident_Type.count()

# %%
derecho_dispatch["Incident Type"].value_counts()
# Out:
# ELECTRICAL HAZARD                                               370
# GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD                      23
# MVA INJURIES:                                                     8
# SMALL OUTSIDE FIRE                                                6
# SMALL BUILDING INVESTIGATION                                      6
#                                                                ...
# WATER PROBLEM WITH ELECTRICAL HAZARD                              1
# OUTSIDE NATURAL GAS ODOR RESIDENTIAL LINE   TANK LESS 5 GALL      1
# OBVIOUS DEATH                                                     1
# POSSIBLY DANGEROUS BODY AREA                                      1
# SEIZURE: EFFECTIVE BREATHING NOT VERIFIED >35                     1
# Name: Incident Type, Length: 122, dtype: int64

# %%
searchfor = ['COMMERCIAL', 'INDUS']
derecho_commercial_industrial = derecho_dispatch[derecho_dispatch['Incident Type'].str.contains('|'.join(searchfor))]

# %%
print(derecho_commercial_industrial)
# Out:
#          Seizure DateTime                       Location        lat  \
# 8     5/3/2020 4:36:42 PM                3000 POSTON AV   36.145332
# 16    5/3/2020 4:39:33 PM               2106 FAIRFAX AV   36.134384
# 18    5/3/2020 4:40:05 PM               188 THOMPSON LN   36.110859
# 22    5/3/2020 4:42:13 PM                 1310 24TH AV S  36.142084
# 25    5/3/2020 4:43:37 PM        607B LARKIN SPRINGS RD   36.253562
# 32    5/3/2020 4:46:29 PM              531 DONELSON PKE   36.146637
# 36    5/3/2020 4:48:18 PM               555 MARRIOTT DR   36.151108
# 41    5/3/2020 4:49:41 PM                  3960 BELL RD   36.166478
# 42    5/3/2020 4:49:41 PM                  3960 BELL RD   36.166478
# 75    5/3/2020 5:06:04 PM              2030 BERNARD CIR   36.131260
# 171   5/3/2020 5:54:04 PM                 2136 CLIFF DR   36.196360
# 200   5/3/2020 6:09:07 PM                 6005 DANA WAY   36.036036
# 221   5/3/2020 6:21:24 PM           5825 CROSSINGS BLVD   36.036319
# 311   5/3/2020 7:06:14 PM       501 BRICK CHURCH PARK DR  36.225123
# 314   5/3/2020 7:07:11 PM                 1310 24TH AV S  36.142084
# 319   5/3/2020 7:09:13 PM           5825 CROSSINGS BLVD   36.036319
# 339   5/3/2020 7:17:53 PM          2284 MURFREESBORO PKE  36.088405
# 355   5/3/2020 7:25:36 PM          1003 HICKORY HILL LN   36.188735
# 374   5/3/2020 7:39:53 PM              2941 LEBANON PKE   36.170832
# 393   5/3/2020 7:49:59 PM  1100 DR MARTIN L KING JR BLVD  36.162155
# 435   5/3/2020 8:18:38 PM              3868 CENTRAL PKE   36.173961
# 450   5/3/2020 8:29:45 PM             1612 ELM HILL PKE   36.145388
# 451   5/3/2020 8:32:26 PM          1003 HICKORY HILL LN   36.188735
# 460   5/3/2020 8:40:46 PM        1211 MEDICAL CENTER DR   36.142407
# 473   5/3/2020 8:47:26 PM                 2515 PARK PLZ   36.152328
# 486   5/3/2020 8:57:24 PM             1612 ELM HILL PKE   36.145388
# 494   5/3/2020 9:04:37 PM          3112 NOLENSVILLE PKE   36.102919
# 571  5/3/2020 10:32:46 PM             3601 TROUSDALE DR   36.097572
# 573  5/3/2020 10:32:52 PM              3529 WEST END AV   36.132296
# 611  5/3/2020 11:45:17 PM          2284 MURFREESBORO PKE  36.088405
# 619  5/4/2020 12:05:58 AM                 2011 HAYES ST   36.151839
# 626  5/4/2020 12:29:50 AM                 2011 HAYES ST   36.151839
#
#            lng                                      Incident Type  \
# 8   -86.815356        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 16  -86.802149        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 18  -86.739307        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 22  -86.803945        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 25  -86.685725        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 32  -86.665777        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 36  -86.689921        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 41  -86.603790        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 42  -86.603790        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 75  -86.789260  SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# 171 -86.825568        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 200 -86.636253  SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# 221 -86.641009        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 311 -86.786586        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 314 -86.803945        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 319 -86.641009        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 339 -86.647480  WATERFLOW ALARM COMMERCIAL COMMERCIAL   INDUST...
# 355 -86.630393        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 374 -86.652582        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 393 -86.791029   PULL STATION ALARM COMMERCIAL   INDUSTRIAL BUILD
# 435 -86.608500        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 450 -86.716072        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 451 -86.630393        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 460 -86.801598        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 473 -86.815607        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 486 -86.716072        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 494 -86.740745  CARBON MONOXIDE ALARM COMMERCIAL   INDUSTRIAL ...
# 571 -86.750366  WATERFLOW ALARM COMMERCIAL COMMERCIAL   INDUST...
# 573 -86.824209        GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 611 -86.647480  WATERFLOW ALARM COMMERCIAL COMMERCIAL   INDUST...
# 619 -86.800791   PULL STATION ALARM COMMERCIAL   INDUSTRIAL BUILD
# 626 -86.800791   PULL STATION ALARM COMMERCIAL   INDUSTRIAL BUILD
#
#                        geometry
# 8    POINT (-86.81536 36.14533)
# 16   POINT (-86.80215 36.13438)
# 18   POINT (-86.73931 36.11086)
# 22   POINT (-86.80395 36.14208)
# 25   POINT (-86.68573 36.25356)
# 32   POINT (-86.66578 36.14664)
# 36   POINT (-86.68992 36.15111)
# 41   POINT (-86.60379 36.16648)
# 42   POINT (-86.60379 36.16648)
# 75   POINT (-86.78926 36.13126)
# 171  POINT (-86.82557 36.19636)
# 200  POINT (-86.63625 36.03604)
# 221  POINT (-86.64101 36.03632)
# 311  POINT (-86.78659 36.22512)
# 314  POINT (-86.80395 36.14208)
# 319  POINT (-86.64101 36.03632)
# 339  POINT (-86.64748 36.08841)
# 355  POINT (-86.63039 36.18873)
# 374  POINT (-86.65258 36.17083)
# 393  POINT (-86.79103 36.16216)
# 435  POINT (-86.60850 36.17396)
# 450  POINT (-86.71607 36.14539)
# 451  POINT (-86.63039 36.18873)
# 460  POINT (-86.80160 36.14241)
# 473  POINT (-86.81561 36.15233)
# 486  POINT (-86.71607 36.14539)
# 494  POINT (-86.74074 36.10292)
# 571  POINT (-86.75037 36.09757)
# 573  POINT (-86.82421 36.13230)
# 611  POINT (-86.64748 36.08841)
# 619  POINT (-86.80079 36.15184)
# 626  POINT (-86.80079 36.15184)

# %%
searchfor = ['ELECTRICAL HAZARD', 'GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD']
derecho_electrical_alarm = derecho_dispatch[derecho_dispatch['Incident Type'].str.contains('|'.join(searchfor))]

# %%
print(derecho_electrical_alarm)
# Out:
#          Seizure DateTime                         Location        lat  \
# 0     5/3/2020 4:31:07 PM                 901 KENWICK CT W  36.046877
# 1     5/3/2020 4:32:18 PM                    8036 ARBOR DR  36.082491
# 4     5/3/2020 4:33:52 PM                615 W HILLWOOD DR  36.129690
# 5     5/3/2020 4:33:53 PM              622 BROOK HOLLOW RD  36.111773
# 6     5/3/2020 4:34:19 PM  JOCELYN HOLLOW RD / BRESSLYN RD  36.103318
# ..                    ...                              ...        ...
# 612  5/3/2020 11:50:16 PM                    5029 SUTER DR  36.070686
# 617  5/3/2020 11:58:29 PM                    2618 ESSEX PL  36.132719
# 618  5/3/2020 11:59:51 PM                 304 ELMINGTON AV  36.133028
# 620  5/4/2020 12:09:25 AM                 5820 LABRADOR LN  36.031867
# 624  5/4/2020 12:22:47 AM                    517 ALBANY DR  36.212754
#
#            lng      Incident Type                    geometry
# 0   -86.962526  ELECTRICAL HAZARD  POINT (-86.96253 36.04688)
# 1   -86.940680  ELECTRICAL HAZARD  POINT (-86.94068 36.08249)
# 4   -86.879834  ELECTRICAL HAZARD  POINT (-86.87983 36.12969)
# 5   -86.888087  ELECTRICAL HAZARD  POINT (-86.88809 36.11177)
# 6   -86.898080  ELECTRICAL HAZARD  POINT (-86.89808 36.10332)
# ..         ...                ...                         ...
# 612 -86.737718  ELECTRICAL HAZARD  POINT (-86.73772 36.07069)
# 617 -86.810791  ELECTRICAL HAZARD  POINT (-86.81079 36.13272)
# 618 -86.822201  ELECTRICAL HAZARD  POINT (-86.82220 36.13303)
# 620 -86.711384  ELECTRICAL HAZARD  POINT (-86.71138 36.03187)
# 624 -86.600431  ELECTRICAL HAZARD  POINT (-86.60043 36.21275)
#
# [399 rows x 6 columns]
